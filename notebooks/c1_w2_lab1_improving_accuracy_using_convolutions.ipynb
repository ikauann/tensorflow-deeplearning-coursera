# %%
import tensorflow as tf

# %%
# carregar o dataset de moda
fmnist = tf.keras.datasets.fashion_mnist

# imagens de treino e teste
(train_images, train_labels), (test_images, test_labels) = fmnist.load_data()

# normalização dos dados
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# definindo o modelo
model = tf.keras.models.Sequential([

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10,  activation=tf.nn.softmax)

])

# configurações dos parametros de treino
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# treinar o modelo
print('Treinando o Modelo: ')
model.fit(train_images, train_labels, epochs=5)

# avalição do modelo com dados de test
print('Avaliação do Modelo: ')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Treinando o Modelo:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.5038 - accuracy: 0.8231
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3784 - accuracy: 0.8644
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3378 - accuracy: 0.8781
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3133 - accuracy: 0.8844
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2951 - accuracy: 0.8913
# Avaliação do Modelo:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3601 - accuracy: 0.8702

# %% [markdown]
# # Rede Neural Convolucional

# %%
# definindo o modelo
model = tf.keras.models.Sequential([

    # adicionar as convoluções e os maxPooling
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(), #
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10,  activation=tf.nn.softmax)

])

# configurações dos parametros de treino
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# sumario do modelo
model.summary()

# treinar o modelo
print('Treinando o Modelo: ')
model.fit(train_images, train_labels, epochs=5)

# avalição do modelo com dados de test
print('Avaliação do Modelo: ')
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Treinando o Modelo:
# Epoch 1/5
# 1875/1875 [==============================] - 107s 56ms/step - loss: 0.4340 - accuracy: 0.8392
# Epoch 2/5
# 1875/1875 [==============================] - 107s 57ms/step - loss: 0.2914 - accuracy: 0.8924
# Epoch 3/5
# 1875/1875 [==============================] - 101s 54ms/step - loss: 0.2459 - accuracy: 0.9092
# Epoch 4/5
# 1875/1875 [==============================] - 101s 54ms/step - loss: 0.2152 - accuracy: 0.9208
# Epoch 5/5
# 1875/1875 [==============================] - 108s 57ms/step - loss: 0.1904 - accuracy: 0.9283
# Avaliação do Modelo:
# 313/313 [==============================] - 6s 17ms/step - loss: 0.2581 - accuracy: 0.9081
